# %%
# %pylab inline
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import warnings
from itertools import product

def invboxcox(y,lmbda):
   if lmbda == 0:
      return(np.exp(y))
   else:
      return(np.exp(np.log(lmbda*y+1)/lmbda))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('WAG_C_M.csv', ';', index_col = ['month'],parse_dates = ['month'], dayfirst = True)

# %%
data.head()
# Out:
#             WAG_C_M
# month
# 1993-01-01     15.3
# 1993-02-01     19.1
# 1993-03-01     23.6
# 1993-04-01     30.6
# 1993-05-01     37.5

# %%
plt.figure(figsize(15,7))
data.WAG_C_M.plot()
plt.ylabel(u'Уровень зарплаты в России')
pylab.show()

# %% [markdown]
# Необходимо стабилизировать дисперсию и убрать тренд, но проверим сначала стационарность и посмотрим на STL-декомпозицию ряда:

# %%
plt.figure(figsize(15,10))
sm.tsa.seasonal_decompose(data.WAG_C_M).plot()
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(data.WAG_C_M)[1])
# Out:
# Критерий Дики-Фуллера: p=0.991850

# %% [markdown]
# Стабилизация дисперсии:
# Сделаем преобразование Бокса-Кокса для стабилизации дисперсии:

# %%
data['WAG'], lmbda = stats.boxcox(data.WAG_C_M)
plt.figure(figsize(15,7))
data.WAG.plot()
plt.ylabel(u'Transformed WAG_C_M')
print("Оптимальный параметр преобразования Бокса-Кокса: %f" % lmbda)
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(data.WAG)[1])
# Out:
# Оптимальный параметр преобразования Бокса-Кокса: 0.263202
# Критерий Дики-Фуллера: p=0.696899

# %% [markdown]
# Данные все еще не стационарны, уровень значимости еще слишком высок.
# Проведем сезонное диференцирование:

# %%
data['WAG_d'] = data.WAG - data.WAG.shift(12)
plt.figure(figsize(15,10))
sm.tsa.seasonal_decompose(data.WAG_d[12:]).plot()
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(data.WAG_d[12:])[1])
# Out:
# Критерий Дики-Фуллера: p=0.014697

# %% [markdown]
# Критерий Дики-Фуллера утверждает что данные стационарны, но мы видим тренд, будем проводить обычное диференцирование:

# %%
data['WAG_d2']= data.WAG_d - data.WAG_d.shift(1)
plt.figure(figsize(15,10))
sm.tsa.seasonal_decompose(data.WAG_d2[13:]).plot()   
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(data.WAG_d2[13:])[1])
# Out:
# Критерий Дики-Фуллера: p=0.000000

# %% [markdown]
# Критерий стационарности уменьшился еще на пару порядков.

# %% [markdown]
# Подбор модели
# Посмотрим на ACF и PACF полученного ряда:

# %%
plt.figure(figsize(15,8))
ax = plt.subplot(211)
sm.graphics.tsa.plot_acf(data.WAG_d2[13:].values.squeeze(), lags=48, ax=ax)
pylab.show()
ax = plt.subplot(212)
sm.graphics.tsa.plot_pacf(data.WAG_d2[13:].values.squeeze(), lags=48, ax=ax)
pylab.show()

# %% [markdown]
# Начальные приближения: Q=0, q=5, P=1, p=5

# %%
ps = range(0, 6)
d=1
qs = range(0, 6)
Ps = range(0, 2)
D=1
Qs = range(0, 1)

# %%
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)
# Out:
# 72

# %%
# %%time
results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')

for param in parameters_list:
    #try except нужен, потому что на некоторых наборах параметров модель не обучается
    try:
        model=sm.tsa.statespace.SARIMAX(data.WAG, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
    #выводим параметры, на которых модель не обучается и переходим к следующему набору
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    #сохраняем лучшую модель, aic, параметры
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
    
warnings.filterwarnings('default')
# Out:
# ('wrong parameters:', (0, 0, 0, 0))
# ('wrong parameters:', (1, 2, 0, 0))
# ('wrong parameters:', (1, 2, 1, 0))
# ('wrong parameters:', (2, 1, 0, 0))
# ('wrong parameters:', (2, 1, 1, 0))
# ('wrong parameters:', (2, 2, 0, 0))
# ('wrong parameters:', (2, 2, 1, 0))
# ('wrong parameters:', (3, 2, 0, 0))
# ('wrong parameters:', (3, 2, 1, 0))
# ('wrong parameters:', (4, 2, 0, 0))
# ('wrong parameters:', (4, 2, 1, 0))
# ('wrong parameters:', (4, 4, 0, 0))
# ('wrong parameters:', (4, 4, 1, 0))
# ('wrong parameters:', (5, 2, 0, 0))
# ('wrong parameters:', (5, 2, 1, 0))
# ('wrong parameters:', (5, 3, 0, 0))
# ('wrong parameters:', (5, 3, 1, 0))
# ('wrong parameters:', (5, 4, 0, 0))
# ('wrong parameters:', (5, 4, 1, 0))
# CPU times: user 1min 11s, sys: 1.08 s, total: 1min 13s
# Wall time: 1min

# %%
result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
# Out:
#       parameters        aic
# 52  (5, 5, 1, 0) -25.917156
# 51  (5, 5, 0, 0) -21.851851
# 20  (1, 5, 1, 0) -15.867145
# 37  (3, 5, 0, 0) -15.250627
# 38  (3, 5, 1, 0) -14.851017

# %%
print(best_model.summary())
# Out:
#                                  Statespace Model Results
# ...
# Dep. Variable:                                WAG   No. Observations:                  284
# Model:             SARIMAX(5, 1, 5)x(1, 1, 0, 12)   Log Likelihood                  24.959
# Date:                            Wed, 02 May 2018   AIC                            -25.917
# Time:                                    21:40:24   BIC                             17.871
# Sample:                                01-01-1993   HQIC                            -8.362
#                                      - 08-01-2016
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0268     14.053      0.002      0.998     -27.516      27.570
# ar.L2          0.0100      9.475      0.001      0.999     -18.561      18.581
# ...

# %% [markdown]
# Остатки:

# %%
plt.figure(figsize(15,8))
plt.subplot(211)
best_model.resid[13:].plot()
plt.ylabel(u'Residuals')
ax = plt.subplot(212)
sm.graphics.tsa.plot_acf(best_model.resid[13:].values.squeeze(), lags=48, ax=ax)

print("Критерий Стьюдента: p=%f" % stats.ttest_1samp(best_model.resid[13:], 0)[1])
print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(best_model.resid[13:])[1])
# Out:
# Критерий Стьюдента: p=0.165453
# Критерий Дики-Фуллера: p=0.000000

# %% [markdown]
# Остатки несмещены (подтверждается критерием Стьюдента) стационарны (подтверждается критерием Дики-Фуллера и визуально), неавтокоррелированы (подтверждается критерием Льюнга-Бокса и коррелограммой). Посмотрим, насколько хорошо модель описывает данные:

# %%
data['model'] = invboxcox(best_model.fittedvalues, lmbda)
plt.figure(figsize(15,7))
data.WAG_C_M.plot()
data.model[13:].plot(color='r')
plt.ylabel('WAG')
pylab.show()

# %% [markdown]
# # Прогноз

# %%
data.shape
# Out:
# (284, 5)

# %%
data2 = data[['WAG_C_M']]
date_list = [datetime.datetime.strptime("2016-08-01", "%Y-%m-%d") + relativedelta(months=x) for x in range(0,36)]
future = pd.DataFrame(index=date_list, columns= data2.columns)
data2 = pd.concat([data2, future])
data2['forecast'] = invboxcox(best_model.predict(start=284, end=319), lmbda)

plt.figure(figsize(15,7))
data2.WAG_C_M.plot()
data2.forecast.plot(color='r')
plt.ylabel('WAG_C_M')
pylab.show()
